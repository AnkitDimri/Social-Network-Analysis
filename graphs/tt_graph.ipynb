# %%
import igraph as ig
import cairocffi as cairo

# %%
from random import ramdom
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-6e619992851a> in <module>
# ----> 1 from random import ramdom
#
# ImportError: cannot import name 'ramdom' from 'random' (/home/ankit/anaconda3/envs/tf/lib/python3.7/random.py)

# %%
tt = ig.Graph (n=100)

vis = set({})

tt.add_edges ([(0,1), (0,2), (0,3)])
vis.add (0)
vis.add (1)
vis.add (2)
vis.add (3)

i = 1

while (len (vis) < 100):
    
    j = i+1
    while j in vis and j < 101:
        j = j+1
        
    tt.add_edges ([(i, j)])
    tt.add_edges ([(i, j+1)])
    vis.add (j)
    vis.add (j+1)
    i = i+1

tt.vs ["color"] = "yellow"
tt.es ["color"] = "blue"
tt.vs ["label"] = [i for i in range (1, 101)]
ig.plot(tt, layout = tt.layout ("kk"))

# %%
print (tt)
# Out:
# IGRAPH U--- 100 99 --
# + attr: color (v), label (v), color (e)
# + edges:
# 0--1 0--2 0--3 1--4 1--5 2--6 2--7 3--8 3--9 4--10 4--11 5--12 5--13 6--14
# 6--15 7--16 7--17 8--18 8--19 9--20 9--21 10--22 10--23 11--24 11--25 12--26
# 12--27 13--28 13--29 14--30 14--31 15--32 15--33 16--34 16--35 17--36 17--37
# 18--38 18--39 19--40 19--41 20--42 20--43 21--44 21--45 22--46 22--47 23--48
# 23--49 24--50 24--51 25--52 25--53 26--54 26--55 27--56 27--57 28--58 28--59
# 29--60 29--61 30--62 30--63 31--64 31--65 32--66 32--67 33--68 33--69 34--70
# 34--71 35--72 35--73 36--74 36--75 37--76 37--77 38--78 38--79 39--80 39--81
# 40--82 40--83 41--84 41--85 42--86 42--87 43--88 43--89 44--90 44--91 45--92
# 45--93 46--94 46--95 47--96 47--97 48--98 48--99
